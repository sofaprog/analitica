# %%
import pandas as pd



# Загрузка данных
df = pd.read_excel('C:/Users/Mi/Downloads/2023-2024 ассесмент база данных.xlsx')
df.columns = df.columns.str.strip()
df_original = df.copy()
# Удаление ненужных столбцов
columns_to_drop = ['ID оценочной сессии', 'Опубликование макета', 'Трудоемкость программы',
                   'Срок реализации программы', 'Целевой уровень развития компетенции',
                   'Дата регистрации', 'Дата начала прохождения оценки']
df.drop(columns=columns_to_drop, inplace=True)

# Преобразуем столбец 'Поток' в два новых столбца
def convert_to_years(year_str):
    start_year = '20' + year_str.split('/')[0]
    end_year = '20' + year_str.split('/')[1]
    return start_year, end_year
df[['Год начала', 'Год окончания']] = df['Поток'].apply(lambda x: pd.Series(convert_to_years(str(x))))

# Преобразуем годы в даты
df['Дата начала'] = pd.to_datetime(df['Год начала'] + '-01-01')
df['Дата окончания'] = pd.to_datetime(df['Год окончания'] + '-01-01')

# Преобразуем числовые столбцы
numeric_cols = ['Результат', 'Количество попыток', 'Время результирующей попытки',
               'Итоговый уровень сформированности компетенций']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# --- ОБЩАЯ СТАТИСТИКА АССЕССМЕНТА ---
# Общие метрики
num_participants = df['ID пользователя'].nunique()
num_graduates = df[df['Статус'] == 'Завершено']['ID пользователя'].nunique()
average_score = df['Результат'].mean()
average_time = df['Время результирующей попытки'].mean()

# Статистика завершения
classification_by_direction = {}
unique_directions = df['Наименование оценочной сессии'].unique()
for direction in unique_directions:
    classification_by_direction[direction] = {
        "Не прошли все 3 этапа": 0,
        "Прошли все 3 этапа": 0,
        "Отчислены": 0
    }
grouped = df.groupby('ID пользователя')
for user_id, user_data in grouped:
    direction = user_data['Наименование оценочной сессии'].iloc[0]
    if "Отчислен" in user_data['Состояние'].values:
        classification_by_direction[direction]["Отчислены"] += 1
    else:
        completed_stages = user_data[user_data['Статус'] == 'Завершено']['Этап оценки'].nunique()
        if completed_stages == 3:
            classification_by_direction[direction]["Прошли все 3 этапа"] += 1
        else:
            classification_by_direction[direction]["Не прошли все 3 этапа"] += 1

# Другие метрики
target_achieved_students = df[df['Итоговый уровень развития компетенции'].isin(['Достигнут', 'Превышен'])]
target_achieved_by_direction = target_achieved_students.groupby('Наименование оценочной сессии')['ID пользователя'].nunique()
listeners_by_direction = df.groupby('Наименование оценочной сессии')['ID пользователя'].nunique()
stage_1_data = df[df['Этап оценки'] == 1]
participants_stage_1_by_direction = stage_1_data.groupby('Наименование оценочной сессии')['ID пользователя'].nunique()

# Вывод результатов первого анализа
print("\nОБЩИЙ АНАЛИЗ")
print(f"\n1. Число участников: {num_participants}")
print(f"2. Число выпускников: {num_graduates}")
print(f"3. Средний балл: {average_score:.2f}")
print(f"4. Среднее время: {average_time:.2f}")

print("\n5. Статистика завершения обучения по направлениям:")
for direction, stats in classification_by_direction.items():
    print(f"\n{direction}:")
    for category, count in stats.items():
        print(f"  {category}: {count}")

print("\n6. Число студентов, достигших целевого показателя:")
print(target_achieved_by_direction.to_string())

print("\n7. Количество слушателей по направлениям:")
print(listeners_by_direction.to_string())

print("\n8. Количество участников на 1 этапе:")
print(participants_stage_1_by_direction.to_string())

# --- УРОВЕНЬ КОМПЕТЕНЦИЙ НА ЭТАПАХ АССЕССМЕНТА ---

# Используем сохраненную копию данных
df = df_original.copy()

# Преобразуем текстовые значения в числовые
level_mapping = {
    'Минимальный исходный': 1,
    'Базовый': 2,
    'Продвинутый': 3,
    'Экспертный': 4
}

# Преобразуем уровни
if df['Итоговый уровень сформированности компетенций'].dtype == 'object':
    df['Итоговый уровень сформированности компетенций'] = (
        df['Итоговый уровень сформированности компетенций']
        .map(level_mapping)
    )

# Удаление ненужных столбцов
columns_to_drop = [
    'ID оценочной сессии', 'Опубликование макета', 'Отраслевая принадлежность',
    'Обучающиеся направления', 'Трудоемкость программы', 'Поток',
    'Срок реализации программы', 'ID пользователя', 'Дата регистрации',
    'Дата начала прохождения оценки', 'Статус', 'Результат',
    'Количество попыток', 'Время результирующей попытки', 'Состояние'
]
df = df.drop(columns=columns_to_drop)

# Удалим строки с пропущенными значениями в уровне компетенций
df = df.dropna(subset=['Итоговый уровень сформированности компетенций'])

# Группировка данных
try:
    grouped = df.groupby(['Этап оценки', 'Наименование оценочной сессии',
                         'Наименование компетенции', 'Итоговый уровень сформированности компетенций']).size().unstack(fill_value=0)

    # Проверим, есть ли данные для анализа
    if not grouped.empty:
        # Расчет процентного соотношения
        percentage_grouped = grouped.div(grouped.sum(axis=1), axis=0) * 100

        # Переименование столбцов
        percentage_grouped = percentage_grouped.rename(columns={
            1: 'Минимальный исходный (%)',
            2: 'Базовый (%)',
            3: 'Продвинутый (%)',
            4: 'Экспертный (%)'
        })

        # Вывод результатов второго анализа
        print("\n\nАНАЛИЗ УРОВНЕЙ СФОРМИРОВАННОСТИ КОМПЕТЕНЦИЙ")
        for (stage, session, competence), data in percentage_grouped.iterrows():
            print(f"\nЭтап оценки: {stage}")
            print(f"Оценочная сессия: {session}")
            print(f"Компетенция: {competence}")
            print("Уровни сформированности компетенций:")
            print(data.to_string())
            print("-" * 50)
    else:
        print("\nНет данных для анализа уровней сформированности компетенций")

except Exception as e:
    print(f"\nОшибка при анализе уровней компетенций: {str(e)}")

# --- СРЕДНИЕ ЗНАЧЕНИЯ ПО НАПРАВЛЕНИЯМ И ГОДАМ ---
print("\n\n АНАЛИЗ СРЕДНИХ ЗНАЧЕНИЙ ")

# Используем сохраненную копию данных
df = df_original.copy()

# Извлекаем год из названия оценочной сессии
df['Год'] = df['Наименование оценочной сессии'].str.extract(r'(\d{4})')

# Альтернативный вариант, если год не извлекается из названия:
if df['Год'].isnull().all():
    df['Год'] = df['Поток'].apply(lambda x: '20' + str(x).split('/')[0] if pd.notnull(x) else None)

# Преобразуем результат в числовой формат
df['Результат'] = pd.to_numeric(df['Результат'], errors='coerce')

# Удаляем строки с пропущенными значениями
df = df.dropna(subset=['Обучающиеся направления', 'Год', 'Результат'])

# Рассчитываем средний балл по направлениям и годам
average_score_by_direction = df.groupby(['Наименование оценочной сессии', 'Год'])['Результат'].mean().reset_index()

# Рассчитываем среднее время по каждому этапу
average_time_by_stage = df.groupby(['Этап оценки', 'Наименование оценочной сессии'])['Время результирующей попытки'].mean().reset_index()

# Среднее количество попыток
average_attempts_by_competency = df.groupby(['Год', 'Наименование оценочной сессии'])['Количество попыток'].mean()

# Рассчитываем средний балл по этапам
average_scores_by_stage = df.groupby(['Год', 'Этап оценки', 'Наименование оценочной сессии'])['Результат'].mean().reset_index()

#Рассчитаем средний балл по компетенциям
average_score_by_competency = df.groupby(['Год', 'Наименование компетенции'])['Результат'].mean()

# Фильтруем данные по первому этапу
first_stage = df[df['Этап оценки'] == 1]

# Рассчитываем средний балл по компетенциям
average_scores_by_competency = first_stage.groupby(['Год', 'Наименование компетенции'])['Результат'].mean().reset_index()

# Вывод результатов
print("\nСредний балл по направлениям и годам:")
print(average_score_by_direction.to_string(index=False))
print("\nСреднее значение времени по каждому этапу:")
print(average_time_by_stage)
print("\nСреднее количество попыток по направлениям и годам:")
print(average_attempts_by_competency)
print("\nСредний балл по этапам и годам:")
print(average_scores_by_stage)
print("\nСредний балл по компетенциям:")
print(average_score_by_competency)
print("\nСредний балл по компетенциям на первом этапе:")
print(average_scores_by_competency)

# --- ВЛИЯНИЕ ВРЕМЕНИ НА РЕЗУЛЬТАТ АССЕССМЕНТА ---
print("\n\n АНАЛИЗ ВЛИЯНИЯ ВРЕМЕНИ НА РЕЗУЛЬТАТЫ ")

# Используем сохраненную копию данных
df = df_original.copy()

# Преобразование данных
df['Время результирующей попытки'] = pd.to_numeric(df['Время результирующей попытки'], errors='coerce')
df['Итоговый уровень сформированности компетенций'] = df['Итоговый уровень сформированности компетенций'].fillna('Не указано')

# Группировка данных по "Наименование оценочной сессии" и "Этап оценки"
grouped_data = df.groupby(['Наименование оценочной сессии', 'Этап оценки'])

# Функция для анализа влияния времени на результаты
def analyze_time_impact(group):
    avg_time = group['Время результирующей попытки'].mean()
    faster_than_avg = group[group['Время результирующей попытки'] < avg_time]
    slower_than_avg = group[group['Время результирующей попытки'] > avg_time]

    faster_results = faster_than_avg['Итоговый уровень сформированности компетенций'].value_counts(normalize=True) * 100
    slower_results = slower_than_avg['Итоговый уровень сформированности компетенций'].value_counts(normalize=True) * 100

    return faster_results, slower_results, avg_time

# Анализ и вывод результатов
for name, group in grouped_data:
    session_name, stage = name
    # Пропускаем группы с недостаточными данными
    if len(group) < 5 or group['Время результирующей попытки'].isnull().all():
        continue

    try:
        faster_results, slower_results, avg_time = analyze_time_impact(group)

        print(f"\nНаименование оценочной сессии: {session_name}, Этап оценки: {stage}")
        print(f"Среднее время прохождения: {avg_time:.2f} минут")
        print("\nРезультаты при прохождении быстрее среднего:")
        print(faster_results.to_string())
        print("\nРезультаты при прохождении дольше среднего:")
        print(slower_results.to_string())
        print("-" * 50)
    except Exception as e:
        print(f"Ошибка при анализе для {session_name}, этап {stage}: {str(e)}")
        continue
# Out:
# ОБЩИЙ АНАЛИЗ
#
# 1. Число участников: 1921
# 2. Число выпускников: 1896
# 3. Средний балл: 0.37
# 4. Среднее время: 33.36
#
# 5. Статистика завершения обучения по направлениям:
#
# 2023 Анализ данных для прикладных областей:
#   Не прошли все 3 этапа: 98
#   Прошли все 3 этапа: 599
#   Отчислены: 5
#
# 2023 Современные технологии получения и анализа данных в «Умном городе»:
#   Не прошли все 3 этапа: 32
#   Прошли все 3 этапа: 280
#   Отчислены: 1
#
# 2023 Разработчик виртуальной и дополненной реальности:
#   Не прошли все 3 этапа: 25
#   Прошли все 3 этапа: 174
#   Отчислены: 2
#
# 2023 Разработка на платформе «1С: Предприятие»:
#   Не прошли все 3 этапа: 16
#   Прошли все 3 этапа: 119
#   Отчислены: 1
#
# 2023 Цифровые технологии управления «Умным городом»:
#   Не прошли все 3 этапа: 42
#   Прошли все 3 этапа: 419
#   Отчислены: 1
#
# 2023 Аналитика больших данных в строительстве:
#   Не прошли все 3 этапа: 25
#   Прошли все 3 этапа: 82
#   Отчислены: 0
#
# 6. Число студентов, достигших целевого показателя:
# Наименование оценочной сессии
# 2023 Анализ данных для прикладных областей                                 649
# 2023 Аналитика больших данных в строительстве                              109
# 2023 Разработка на платформе «1С: Предприятие»                             134
# 2023 Разработчик виртуальной и дополненной реальности                      190
# 2023 Современные технологии получения и анализа данных в «Умном городе»    293
# 2023 Цифровые технологии управления «Умным городом»                        438
#
# 7. Количество слушателей по направлениям:
# Наименование оценочной сессии
# 2023 Анализ данных для прикладных областей                                 739
# 2023 Аналитика больших данных в строительстве                              119
# 2023 Разработка на платформе «1С: Предприятие»                             154
# 2023 Разработчик виртуальной и дополненной реальности                      211
# 2023 Современные технологии получения и анализа данных в «Умном городе»    340
# 2023 Цифровые технологии управления «Умным городом»                        499
#
# 8. Количество участников на 1 этапе:
# Наименование оценочной сессии
# 2023 Анализ данных для прикладных областей                                 739
# 2023 Аналитика больших данных в строительстве                              119
# 2023 Разработка на платформе «1С: Предприятие»                             154
# 2023 Разработчик виртуальной и дополненной реальности                      211
# 2023 Современные технологии получения и анализа данных в «Умном городе»    340
# 2023 Цифровые технологии управления «Умным городом»                        499
#
#
# АНАЛИЗ УРОВНЕЙ СФОРМИРОВАННОСТИ КОМПЕТЕНЦИЙ
#
# Этап оценки: 1
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    58.166189
# Базовый (%)                 34.527221
# Продвинутый (%)              7.306590
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Применяет принципы и основы алгоритмизации
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    53.295129
# Базовый (%)                 37.965616
# Продвинутый (%)              8.309456
# Экспертный (%)               0.429799
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Использует средства компьютерного моделирования
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    12.727273
# Базовый (%)                 35.454545
# Продвинутый (%)             41.818182
# Экспертный (%)              10.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    44.545455
# Базовый (%)                 34.545455
# Продвинутый (%)             20.909091
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    50.724638
# Базовый (%)                 44.927536
# Продвинутый (%)              4.347826
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Разрабатывает программное обеспечение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    36.231884
# Базовый (%)                 44.202899
# Продвинутый (%)             19.565217
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Конструирует левел-дизайн
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    44.221106
# Базовый (%)                 38.693467
# Продвинутый (%)             17.085427
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет технологии виртуальной и дополненной реальностей
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    42.211055
# Базовый (%)                 42.713568
# Продвинутый (%)             15.075377
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    30.653266
# Базовый (%)                 43.718593
# Продвинутый (%)             23.618090
# Экспертный (%)               2.010050
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Анализирует большие данные
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    61.538462
# Базовый (%)                 31.410256
# Продвинутый (%)              7.051282
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    58.012821
# Базовый (%)                 35.576923
# Продвинутый (%)              6.410256
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Применяет Искусственный интеллект и машинное обучение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    54.807692
# Базовый (%)                 38.461538
# Продвинутый (%)              6.730769
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    53.508772
# Базовый (%)                 39.692982
# Продвинутый (%)              6.798246
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 1
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Проектирует и реорганизует бизнес-процессы предприятия
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    47.807018
# Базовый (%)                 43.640351
# Продвинутый (%)              8.552632
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    43.779528
# Базовый (%)                 40.000000
# Продвинутый (%)             15.905512
# Экспертный (%)               0.314961
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Применяет принципы и основы алгоритмизации
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    38.110236
# Базовый (%)                 47.244094
# Продвинутый (%)             14.645669
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Использует средства компьютерного моделирования
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    16.666667
# Базовый (%)                 26.190476
# Продвинутый (%)             50.000000
# Экспертный (%)               7.142857
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    28.571429
# Базовый (%)                 48.809524
# Продвинутый (%)             22.619048
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    46.511628
# Базовый (%)                 39.534884
# Продвинутый (%)             13.953488
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Разрабатывает программное обеспечение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    22.480620
# Базовый (%)                 51.937984
# Продвинутый (%)             25.581395
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Конструирует левел-дизайн
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    38.888889
# Базовый (%)                 38.333333
# Продвинутый (%)             22.777778
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет технологии виртуальной и дополненной реальностей
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    36.111111
# Базовый (%)                 44.444444
# Продвинутый (%)             19.444444
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    26.111111
# Базовый (%)                 41.666667
# Продвинутый (%)             30.555556
# Экспертный (%)               1.666667
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Анализирует большие данные
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    58.219178
# Базовый (%)                 32.876712
# Продвинутый (%)              8.904110
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    43.493151
# Базовый (%)                 40.410959
# Продвинутый (%)             15.753425
# Экспертный (%)               0.342466
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Применяет Искусственный интеллект и машинное обучение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    38.698630
# Базовый (%)                 44.178082
# Продвинутый (%)             16.780822
# Экспертный (%)               0.342466
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    51.388889
# Базовый (%)                 40.972222
# Продвинутый (%)              7.638889
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 2
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Проектирует и реорганизует бизнес-процессы предприятия
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    41.435185
# Базовый (%)                 46.759259
# Продвинутый (%)             11.805556
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    38.576159
# Базовый (%)                 44.205298
# Продвинутый (%)             16.390728
# Экспертный (%)               0.827815
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Анализ данных для прикладных областей
# Компетенция: Применяет принципы и основы алгоритмизации
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    32.781457
# Базовый (%)                 49.006623
# Продвинутый (%)             16.556291
# Экспертный (%)               1.655629
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Использует средства компьютерного моделирования
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    20.731707
# Базовый (%)                 29.268293
# Продвинутый (%)             40.243902
# Экспертный (%)               9.756098
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Аналитика больших данных в строительстве
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    24.390244
# Базовый (%)                 51.219512
# Продвинутый (%)             23.170732
# Экспертный (%)               1.219512
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    39.669421
# Базовый (%)                 41.322314
# Продвинутый (%)             19.008264
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Разработка на платформе «1С: Предприятие»
# Компетенция: Разрабатывает программное обеспечение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    27.272727
# Базовый (%)                 41.322314
# Продвинутый (%)             29.752066
# Экспертный (%)               1.652893
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Конструирует левел-дизайн
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    26.011561
# Базовый (%)                 44.508671
# Продвинутый (%)             29.479769
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет технологии виртуальной и дополненной реальностей
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    25.433526
# Базовый (%)                 46.242775
# Продвинутый (%)             27.745665
# Экспертный (%)               0.578035
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Разработчик виртуальной и дополненной реальности
# Компетенция: Применяет языки программирования для решения профессиональных задач
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    24.277457
# Базовый (%)                 47.398844
# Продвинутый (%)             26.011561
# Экспертный (%)               2.312139
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Анализирует большие данные
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    45.195730
# Базовый (%)                 44.839858
# Продвинутый (%)              9.964413
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    34.163701
# Базовый (%)                 39.145907
# Продвинутый (%)             24.555160
# Экспертный (%)               2.135231
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Современные технологии получения и анализа данных в «Умном городе»
# Компетенция: Применяет Искусственный интеллект и машинное обучение
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    32.740214
# Базовый (%)                 43.416370
# Продвинутый (%)             23.487544
# Экспертный (%)               0.355872
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Дорабатывает конфигурации и модули ИС (информационные системы) предприятий
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    44.893112
# Базовый (%)                 42.280285
# Продвинутый (%)             12.826603
# Экспертный (%)               0.000000
# --------------------------------------------------
#
# Этап оценки: 3
# Оценочная сессия: 2023 Цифровые технологии управления «Умным городом»
# Компетенция: Проектирует и реорганизует бизнес-процессы предприятия
# Уровни сформированности компетенций:
# Итоговый уровень сформированности компетенций
# Минимальный исходный (%)    37.292162
# Базовый (%)                 47.980998
# Продвинутый (%)             14.726841
# Экспертный (%)               0.000000
# --------------------------------------------------
#
#
#  АНАЛИЗ СРЕДНИХ ЗНАЧЕНИЙ
#
# Средний балл по направлениям и годам:
#                                           Наименование оценочной сессии  Год  Результат
#                              2023 Анализ данных для прикладных областей 2023   0.360378
#                           2023 Аналитика больших данных в строительстве 2023   0.474199
#                          2023 Разработка на платформе «1С: Предприятие» 2023   0.394340
#                   2023 Разработчик виртуальной и дополненной реальности 2023   0.408501
# 2023 Современные технологии получения и анализа данных в «Умном городе» 2023   0.347746
#                     2023 Цифровые технологии управления «Умным городом» 2023   0.352325
#
# Среднее значение времени по каждому этапу:
#     Этап оценки                      Наименование оценочной сессии  \
# 0             1         2023 Анализ данных для прикладных областей
# 1             1      2023 Аналитика больших данных в строительстве
# 2             1     2023 Разработка на платформе «1С: Предприятие»
# 3             1  2023 Разработчик виртуальной и дополненной реа...
# 4             1  2023 Современные технологии получения и анализ...
# 5             1  2023 Цифровые технологии управления «Умным гор...
# 6             2         2023 Анализ данных для прикладных областей
# 7             2      2023 Аналитика больших данных в строительстве
# 8             2     2023 Разработка на платформе «1С: Предприятие»
# 9             2  2023 Разработчик виртуальной и дополненной реа...
# 10            2  2023 Современные технологии получения и анализ...
# 11            2  2023 Цифровые технологии управления «Умным гор...
# 12            3         2023 Анализ данных для прикладных областей
# 13            3      2023 Аналитика больших данных в строительстве
# 14            3     2023 Разработка на платформе «1С: Предприятие»
# 15            3  2023 Разработчик виртуальной и дополненной реа...
# 16            3  2023 Современные технологии получения и анализ...
# 17            3  2023 Цифровые технологии управления «Умным гор...
#
#    Время результирующей попытки
# 0                     27.789398
# 1                     27.209091
# 2                     36.949275
# 3                     45.668342
# 4                     37.304487
# 5                     31.508772
# 6                     32.144882
# 7                     27.380952
# 8                     37.062016
# 9                     42.388889
# 10                     44.14726
# 11                    33.585648
# 12                    24.781457
# 13                     24.02439
# 14                    29.421488
# 15                    36.560694
# 16                    36.007117
# 17                    27.213777
#
# Среднее количество попыток по направлениям и годам:
# Год   Наименование оценочной сессии
# 2023  2023 Анализ данных для прикладных областей                                 1.028911
#       2023 Аналитика больших данных в строительстве                               1.01087
#       2023 Разработка на платформе «1С: Предприятие»                             1.020619
#       2023 Разработчик виртуальной и дополненной реальности                      1.023551
#       2023 Современные технологии получения и анализа данных в «Умном городе»    1.037288
#       2023 Цифровые технологии управления «Умным городом»                        1.031322
# Name: Количество попыток, dtype: object
#
# Средний балл по этапам и годам:
#      Год  Этап оценки                      Наименование оценочной сессии  \
# 0   2023            1         2023 Анализ данных для прикладных областей
# 1   2023            1      2023 Аналитика больших данных в строительстве
# 2   2023            1     2023 Разработка на платформе «1С: Предприятие»
# 3   2023            1  2023 Разработчик виртуальной и дополненной реа...
# 4   2023            1  2023 Современные технологии получения и анализ...
# 5   2023            1  2023 Цифровые технологии управления «Умным гор...
# 6   2023            2         2023 Анализ данных для прикладных областей
# 7   2023            2      2023 Аналитика больших данных в строительстве
# 8   2023            2     2023 Разработка на платформе «1С: Предприятие»
# 9   2023            2  2023 Разработчик виртуальной и дополненной реа...
# 10  2023            2  2023 Современные технологии получения и анализ...
# 11  2023            2  2023 Цифровые технологии управления «Умным гор...
# 12  2023            3         2023 Анализ данных для прикладных областей
# 13  2023            3      2023 Аналитика больших данных в строительстве
# 14  2023            3     2023 Разработка на платформе «1С: Предприятие»
# 15  2023            3  2023 Разработчик виртуальной и дополненной реа...
# 16  2023            3  2023 Современные технологии получения и анализ...
# 17  2023            3  2023 Цифровые технологии управления «Умным гор...
#
#     Результат
# 0    0.321335
# 1    0.462638
# 2    0.367809
# 3    0.379422
# 4    0.307514
# 5    0.336540
# 6    0.370162
# 7    0.478130
# 8    0.405802
# 9    0.409848
# 10   0.348104
# 11   0.351562
# 12   0.395212
# 13   0.485680
# 14   0.412378
# 15   0.440547
# 16   0.392043
# 17   0.370204
#
# Средний балл по компетенциям:
# Год   Наименование компетенции
# 2023  Анализирует большие данные                                                              0.312421
#       Дорабатывает конфигурации и модули ИС (информационные системы) предприятий              0.344230
#       Использует средства компьютерного моделирования                                         0.541969
#       Конструирует левел-дизайн                                                               0.388587
#       Осуществляет сбор и подготовку данных для обучения моделей искусственного интеллекта    0.357449
#       Применяет Искусственный интеллект и машинное обучение                                   0.365229
#       Применяет принципы и основы алгоритмизации                                              0.367027
#       Применяет технологии виртуальной и дополненной реальностей                              0.394722
#       Применяет языки программирования для решения профессиональных задач                     0.430272
#       Проектирует и реорганизует бизнес-процессы предприятия                                  0.365402
#       Разрабатывает программное обеспечение                                                   0.427640
# Name: Результат, dtype: float64
#
# Средний балл по компетенциям на первом этапе:
#      Год                           Наименование компетенции  Результат
# 0   2023                         Анализирует большие данные   0.289603
# 1   2023  Дорабатывает конфигурации и модули ИС (информа...   0.327097
# 2   2023    Использует средства компьютерного моделирования   0.551377
# 3   2023                          Конструирует левел-дизайн   0.348713
# 4   2023  Осуществляет сбор и подготовку данных для обуч...   0.313389
# 5   2023  Применяет Искусственный интеллект и машинное о...   0.321581
# 6   2023         Применяет принципы и основы алгоритмизации   0.328373
# 7   2023  Применяет технологии виртуальной и дополненной...   0.361162
# 8   2023  Применяет языки программирования для решения п...   0.408993
# 9   2023  Проектирует и реорганизует бизнес-процессы пре...   0.349399
# 10  2023              Разрабатывает программное обеспечение   0.397233
#
#
#  АНАЛИЗ ВЛИЯНИЯ ВРЕМЕНИ НА РЕЗУЛЬТАТЫ
#
# Наименование оценочной сессии: 2023 Анализ данных для прикладных областей, Этап оценки: 1
# Среднее время прохождения: 27.79 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    62.650602
# Базовый                 31.325301
# Продвинутый              5.903614
# Экспертный               0.120482
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    45.583039
# Базовый                 43.462898
# Продвинутый             10.600707
# Экспертный               0.353357
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Анализ данных для прикладных областей, Этап оценки: 2
# Среднее время прохождения: 32.14 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    49.725275
# Базовый                 39.835165
# Продвинутый             10.439560
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 48.708487
# Минимальный исходный    29.151292
# Продвинутый             21.771218
# Экспертный               0.369004
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Анализ данных для прикладных областей, Этап оценки: 3
# Среднее время прохождения: 24.78 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    46.358543
# Базовый                 42.436975
# Продвинутый             10.364146
# Экспертный               0.840336
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 52.631579
# Продвинутый             25.303644
# Минимальный исходный    20.242915
# Экспертный               1.821862
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Аналитика больших данных в строительстве, Этап оценки: 1
# Среднее время прохождения: 27.21 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 36.428571
# Минимальный исходный    35.714286
# Продвинутый             23.571429
# Экспертный               4.285714
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Продвинутый             45.00
# Базовый                 32.50
# Минимальный исходный    16.25
# Экспертный               6.25
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Аналитика больших данных в строительстве, Этап оценки: 2
# Среднее время прохождения: 27.38 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 45.744681
# Минимальный исходный    30.851064
# Продвинутый             21.276596
# Экспертный               2.127660
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Продвинутый             55.405405
# Базовый                 27.027027
# Минимальный исходный    12.162162
# Экспертный               5.405405
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Аналитика больших данных в строительстве, Этап оценки: 3
# Среднее время прохождения: 24.02 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 40.425532
# Минимальный исходный    31.914894
# Продвинутый             25.531915
# Экспертный               2.127660
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 40.0
# Продвинутый             40.0
# Экспертный              10.0
# Минимальный исходный    10.0
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработка на платформе «1С: Предприятие», Этап оценки: 1
# Среднее время прохождения: 36.95 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    57.792208
# Базовый                 35.714286
# Продвинутый              6.493506
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 55.737705
# Минимальный исходный    25.409836
# Продвинутый             18.852459
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработка на платформе «1С: Предприятие», Этап оценки: 2
# Среднее время прохождения: 37.06 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 42.666667
# Минимальный исходный    42.000000
# Продвинутый             15.333333
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 50.000000
# Продвинутый             25.925926
# Минимальный исходный    24.074074
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработка на платформе «1С: Предприятие», Этап оценки: 3
# Среднее время прохождения: 29.42 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    42.957746
# Базовый                 40.845070
# Продвинутый             15.492958
# Экспертный               0.704225
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 42.0
# Продвинутый             37.0
# Минимальный исходный    20.0
# Экспертный               1.0
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработчик виртуальной и дополненной реальности, Этап оценки: 1
# Среднее время прохождения: 45.67 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    49.287749
# Базовый                 36.752137
# Продвинутый             13.960114
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 48.780488
# Продвинутый             25.203252
# Минимальный исходный    24.390244
# Экспертный               1.626016
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработчик виртуальной и дополненной реальности, Этап оценки: 2
# Среднее время прохождения: 42.39 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 41.741742
# Минимальный исходный    39.939940
# Продвинутый             17.717718
# Экспертный               0.600601
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 41.062802
# Продвинутый             34.782609
# Минимальный исходный    23.671498
# Экспертный               0.483092
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Разработчик виртуальной и дополненной реальности, Этап оценки: 3
# Среднее время прохождения: 36.56 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 50.00000
# Минимальный исходный    31.17284
# Продвинутый             18.82716
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Продвинутый             42.564103
# Базовый                 39.487179
# Минимальный исходный    15.384615
# Экспертный               2.564103
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Современные технологии получения и анализа данных в «Умном городе», Этап оценки: 1
# Среднее время прохождения: 37.30 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    69.047619
# Базовый                 27.721088
# Продвинутый              3.231293
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 47.701149
# Минимальный исходный    39.655172
# Продвинутый             12.643678
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Современные технологии получения и анализа данных в «Умном городе», Этап оценки: 2
# Среднее время прохождения: 44.15 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    55.865922
# Базовый                 32.960894
# Продвинутый             10.986965
# Экспертный               0.186220
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 48.967552
# Минимальный исходный    32.448378
# Продвинутый             18.289086
# Экспертный               0.294985
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Современные технологии получения и анализа данных в «Умном городе», Этап оценки: 3
# Среднее время прохождения: 36.01 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    45.996276
# Базовый                 40.037244
# Продвинутый             13.407821
# Экспертный               0.558659
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 46.732026
# Продвинутый             29.738562
# Минимальный исходный    22.222222
# Экспертный               1.307190
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Цифровые технологии управления «Умным городом», Этап оценки: 1
# Среднее время прохождения: 31.51 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    57.031250
# Базовый                 38.867188
# Продвинутый              4.101562
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 45.25
# Минимальный исходный    42.50
# Продвинутый             12.25
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Цифровые технологии управления «Умным городом», Этап оценки: 2
# Среднее время прохождения: 33.59 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    53.571429
# Базовый                 39.484127
# Продвинутый              6.944444
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 50.000000
# Минимальный исходный    36.388889
# Продвинутый             13.611111
# --------------------------------------------------
#
# Наименование оценочной сессии: 2023 Цифровые технологии управления «Умным городом», Этап оценки: 3
# Среднее время прохождения: 27.21 минут
#
# Результаты при прохождении быстрее среднего:
# Итоговый уровень сформированности компетенций
# Минимальный исходный    51.234568
# Базовый                 42.798354
# Продвинутый              5.967078
#
# Результаты при прохождении дольше среднего:
# Итоговый уровень сформированности компетенций
# Базовый                 48.314607
# Минимальный исходный    27.247191
# Продвинутый             24.438202
# --------------------------------------------------

# %%
import pandas as pd
import os
from datetime import datetime

# ... (ваш предыдущий код до создания final_df остается без изменений) ...

# Создаем словарь для сбора всех данных
data_dict = {}

# --- ОБРАБОТКА СТАТИСТИКИ ЗАВЕРШЕНИЯ ОБУЧЕНИЯ ---
for direction, stats in classification_by_direction.items():
    for category, count in stats.items():
        data_dict[f"Статистика/{direction}/{category}"] = count

# --- ОБРАБОТКА ДОСТИЖЕНИЯ ЦЕЛЕВОГО ПОКАЗАТЕЛЯ ---
for direction, count in target_achieved_by_direction.items():
    data_dict[f"Целевые показатели/{direction}/Достигли"] = count

# --- ОБРАБОТКА КОЛИЧЕСТВА СЛУШАТЕЛЕЙ ---
for direction, count in listeners_by_direction.items():
    data_dict[f"Участники/{direction}/Общее количество"] = count

# --- ОБРАБОТКА УЧАСТНИКОВ 1 ЭТАПА ---
for direction, count in participants_stage_1_by_direction.items():
    data_dict[f"Участники/{direction}/1 этап"] = count

# --- ОБРАБОТКА СРЕДНИХ ЗНАЧЕНИЙ ---
if not average_score_by_direction.empty:
    for idx, row in average_score_by_direction.iterrows():
        direction = row['Наименование оценочной сессии']
        year = row['Год']
        data_dict[f"Средние значения/{direction}/Средний балл ({year})"] = row['Результат']

if not average_time_by_stage.empty:
    for idx, row in average_time_by_stage.iterrows():
        direction = row['Наименование оценочной сессии']
        stage = row['Этап оценки']
        data_dict[f"Средние значения/{direction}/Среднее время (этап {stage})"] = row['Время результирующей попытки']

# --- ОБРАБОТКА УРОВНЕЙ КОМПЕТЕНЦИЙ ---
if 'percentage_grouped' in locals():
    for (stage, session, competence), data in percentage_grouped.iterrows():
        data_dict[f"Уровни компетенций/{session}/Этап {stage}/{competence}/Базовый (%)"] = data['Базовый (%)']
        data_dict[f"Уровни компетенций/{session}/Этап {stage}/{competence}/Продвинутый (%)"] = data['Продвинутый (%)']
        data_dict[f"Уровни компетенций/{session}/Этап {stage}/{competence}/Экспертный (%)"] = data['Экспертный (%)']
        data_dict[f"Уровни компетенций/{session}/Этап {stage}/{competence}/Минимальный исходный (%)"] = data['Минимальный исходный (%)']

# --- ОБРАБОТКА ВЛИЯНИЯ ВРЕМЕНИ НА РЕЗУЛЬТАТЫ ---
if 'grouped_data' in locals():
    for name, group in grouped_data:
        session_name, stage = name
        if len(group) < 5 or group['Время результирующей попытки'].isnull().all():
            continue
        
        try:
            faster_results, slower_results, avg_time = analyze_time_impact(group)
            
            # Добавляем среднее время
            data_dict[f"Влияние времени/{session_name}/Этап {stage}/Среднее время"] = avg_time
            
            # Добавляем результаты для быстрых участников по уровням
            for level, percent in faster_results.items():
                level_name = {
                    1: "Минимальный исходный",
                    2: "Базовый",
                    3: "Продвинутый",
                    4: "Экспертный"
                }.get(level, str(level))
                data_dict[f"Влияние времени/{session_name}/Этап {stage}/Быстрее среднего/{level_name}"] = percent
            
            # Добавляем результаты для медленных участников по уровням
            for level, percent in slower_results.items():
                level_name = {
                    1: "Минимальный исходный",
                    2: "Базовый",
                    3: "Продвинутый",
                    4: "Экспертный"
                }.get(level, str(level))
                data_dict[f"Влияние времени/{session_name}/Этап {stage}/Медленнее среднего/{level_name}"] = percent
                
        except Exception as e:
            continue
# --- ОБРАБОТКА СРЕДНИХ ЗНАЧЕНИЙ ПО КОМПЕТЕНЦИЯМ ---

# Средний балл по компетенциям (все этапы вместе)
if not average_score_by_competency.empty:
    for (year, competence), score in average_score_by_competency.items():
        data_dict[f"Средние значения по компетенциям/Все этапы/{year}/{competence}"] = score

# Средний балл по компетенциям по этапам
if not average_scores_by_competency_stage.empty:
    for idx, row in average_scores_by_competency_stage.iterrows():
        year = row['Год']
        stage = row['Этап оценки']
        competence = row['Наименование компетенции']
        score = row['Результат']
        data_dict[f"Средние значения по компетенциям/Этап {stage}/{year}/{competence}"] = score

# --- ОБРАБОТКА СРЕДНИХ ЗНАЧЕНИЙ ПО ЭТАПАМ ---
if not average_scores_by_stage.empty:
    for idx, row in average_scores_by_stage.iterrows():
        year = row['Год']
        stage = row['Этап оценки']
        direction = row['Наименование оценочной сессии']
        score = row['Результат']
        data_dict[f"Средние значения по этапам/{direction}/Этап {stage} ({year})"] = score

# --- СОЗДАЕМ ИТОГОВЫЙ DATAFRAME ---
final_df = pd.DataFrame.from_dict(data_dict, orient='index', columns=['Значение'])

# --- ФОРМАТИРУЕМ ВЫВОД ---
final_df.index = final_df.index.str.split('/').map(lambda x: " | ".join(x))

# --- ВЫВОД И СОХРАНЕНИЕ ---
print("\nИТОГОВАЯ СВОДНАЯ ТАБЛИЦА:")
print(final_df.sort_index())

try:
    # Создаем уникальное имя файла
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_file = f"итоговый_анализ_{timestamp}.xlsx"
    
    # Пробуем сохранить на рабочий стол
    desktop_path = os.path.join(os.path.expanduser('~'), 'Desktop')
    save_path = os.path.join(desktop_path, output_file)
    
    # Создаем директорию если нужно
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    # Сохраняем файл с красивыми заголовками
    final_df.reset_index().rename(columns={'index': 'Метрика'}).to_excel(
        save_path, 
        index=False,
        sheet_name='Результаты асессмента'
    )
    print(f"\nФайл успешно сохранен: {save_path}")
    
except PermissionError:
    print("\nОшибка: Нет доступа к файлу. Закройте Excel и попробуйте снова.")
except Exception as e:
    print(f"\nОшибка при сохранении: {str(e)}")
    print("Попробуйте сохранить вручную:")
    print(final_df)
# Out:
# ИТОГОВАЯ СВОДНАЯ ТАБЛИЦА:
#                                                       Значение
# Влияние времени | 2023 Анализ данных для прикла...   31.325301
# Влияние времени | 2023 Анализ данных для прикла...   62.650602
# Влияние времени | 2023 Анализ данных для прикла...    5.903614
# Влияние времени | 2023 Анализ данных для прикла...    0.120482
# Влияние времени | 2023 Анализ данных для прикла...   43.462898
# ...                                                        ...
# Целевые показатели | 2023 Аналитика больших дан...  109.000000
# Целевые показатели | 2023 Разработка на платфор...  134.000000
# Целевые показатели | 2023 Разработчик виртуальн...  190.000000
# Целевые показатели | 2023 Современные технологи...  293.000000
# Целевые показатели | 2023 Цифровые технологии у...  438.000000
#
# [437 rows x 1 columns]
#
# Файл успешно сохранен: C:\Users\Mi\Desktop\итоговый_анализ_20250405_113445.xlsx
